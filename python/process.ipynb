# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_json("/Users/user/Desktop/Developer/jupyter/Titanic-Details/Backend/data/titanic.json")
print(df.head())
df.plot()
# Out:
#                name  age     sex  pclass   fare cabin embarked    status
# 0     Jason Stevens   21    male       2  99.05   F87        Q      Died
# 1    Andrew Daniels    8  female       3  47.36   B34        C      Died
# 2    Eddie Anderson    5  female       3  14.03  A107        C  Survived
# 3     Jeffrey Walsh    1    male       1  15.38   D29        S      Died
# 4  Michael Williams   41  female       3  86.17  B143        Q  Survived
# <Axes: >

# %% [markdown]
# # Survived Vs Dead Count

# %%
sns.countplot(data=df, x='status')
plt.title("Survival Count")
plt.show()

# %% [markdown]
# # Age Distribution

# %%
sns.histplot(df['age'], kde= True)
plt.title("Age Distribution")
plt.show()
